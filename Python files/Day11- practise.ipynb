# %%
import pandas as pd

df= pd.read_csv("C:\\Users\\User\\Desktop\\Python files\\data\\car-sales-extended-missing-data.csv")
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
df.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
df.shape
# Out:
# (1000, 5)

# %%
df= df[df["Price"].notna()]
df.isna().sum(), df.shape
# Out:
# (Make             47
#  Colour           46
#  Odometer (KM)    48
#  Doors            47
#  Price             0
#  dtype: int64,
#  (950, 5))

# %%
x= df.drop("Price", axis=1)
y= df["Price"]

x.shape, y.shape
# Out:
# ((950, 4), (950,))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer

# %%
df["Make"].mode(), df["Doors"].mode(), df["Odometer (KM)"].mean();

# %%
# from sklearn.compose import ColumnTransfromer
# from sklearn.impute import SimpleImputer


#how to impute

first_impute = SimpleImputer(strategy="mean")
second_impute = SimpleImputer(strategy="constant", fill_value= 4)
third_impute = SimpleImputer(strategy="most_frequent")

#what to fill 
first_fill = ["Odometer (KM)"]
second_fill = ["Doors"]
third_fill = ["Colour", "Make"]

#how to fill what

filled_x = ColumnTransformer([("first_impute", first_impute, first_fill),
                                             ("second_impute", second_impute, second_fill),
                                             ("third_impute", third_impute, third_fill)],
                               remainder= "passthrough")
#view the model
filled_x
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('first_impute', SimpleImputer(),
#                                  ['Odometer (KM)']),
#                                 ('second_impute',
#                                  SimpleImputer(fill_value=4,
#                                                strategy='constant'),
#                                  ['Doors']),
#                                 ('third_impute',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  ['Colour', 'Make'])])

# %%
#file the model
filled_x= filled_x.fit_transform(x)
filled_x
# Out:
# array([[35431.0, 4.0, 'White', 'Honda'],
#        [192714.0, 5.0, 'Blue', 'BMW'],
#        [84714.0, 4.0, 'White', 'Honda'],
#        ...,
#        [66604.0, 4.0, 'Blue', 'Nissan'],
#        [215883.0, 4.0, 'White', 'Honda'],
#        [248360.0, 4.0, 'Blue', 'Toyota']], shape=(950, 4), dtype=object)

# %%
#transform back to dataframe
x = pd.DataFrame(filled_x, columns=x.get_feature_names_out())
#x.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19288\3841063705.py in ?()
#       1 #transform back to dataframe
# ----> 2 x = pd.DataFrame(filled_x, columns=x.get_feature_names_out())
#       3 #x.isna().sum()
#
# D:\on-side installations\Anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_feature_names_out'
