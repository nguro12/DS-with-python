# %% [markdown]
# ### making sure all the data is numerical

# %%
import pandas as pd

# %%
df= pd.read_csv("C:\\Users\\User\\Desktop\\Python files\\data\\car-sales-extended.csv")
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
df["Make"].value_counts()
# Out:
# Make
# Toyota    398
# Honda     304
# Nissan    198
# BMW       100
# Name: count, dtype: int64

# %% [markdown]
# ### Turn categories into numbers

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
x = df.drop("Price", axis =1 )
y= df["Price"]
x.shape, y.shape
# Out:
# ((1000, 4), (1000,))

# %%
# transform the data
ohe= One
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
cat_cols =  ["Make", "Colour", "Doors" ] #check how this code works

one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot",
                                 one_hot,
                                 cat_cols)],
                               remainder = "passthrough")
tdf= transformer.fit_transform(df)
tdf;

# %%
tdf= pd.DataFrame(tdf)
tdf

# %% [markdown]
# # Alternative method to transform  categories into digits

# %%
# dummies= pd.get_dummies(df[["Make", "Colour", "Doors"]])
# dummies
ttdf.dtypes

# %%
# split the data
x= tdf.drop(["Make", "Colour", "Doors" ])
y = tdf['Price']
x.shape, y.shape

# %%
# fit and train the model
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = trian_test_split(x)

x_train.shape, x_test.shape, y_train.shape, y_test.shape

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import pandas as pd

# Separate features and target
X = df.drop("Price", axis=1)
y = df["Price"]

# Categorical columns
cat_cols = ["Make", "Colour", "Doors"]

# Transformer
transformer = ColumnTransformer(transformers=[
        ("one_hot", OneHotEncoder(handle_unknown="ignore"), cat_cols)],
    remainder="passthrough")

# Transform features
X_transformed = transformer.fit_transform(X)

# Optional: convert to DataFrame
X_transformed = pd.DataFrame(
    X_transformed,
    columns=transformer.get_feature_names_out(),
    index=X.index
)

X_transformed.shape, y.shape
